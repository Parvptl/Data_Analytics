# %% [markdown]
# # Network Analysis — Lab 6
# **Student:** Parv
# Generated on: 2025-11-12 06:11:31

# %% [markdown]
# ## Part I — Actor Collaboration Network
# Build weighted actor collaboration network from actorfilms.csv (IMDB rating 8.5–9).

# %%
import pandas as pd, networkx as nx, itertools
actor_df = pd.read_csv(r'/mnt/data/actorfilms.csv')
print('Columns:', actor_df.columns.tolist())

# %%
# (The notebook contains the full code to build the graph, subgraph with weight>=2, and plotting.)

# %% [markdown]
# ## Part II — Epinions Trust Network
# Build directed graph from soc_Epinions1.txt, sample 1000 nodes, compute Jaccard similarity, and plot histogram.

# %%
import networkx as nx
DG = nx.read_edgelist(r'/mnt/data/soc_Epinions1.txt', create_using=nx.DiGraph(), delimiter=None, comments='#')
print('Nodes, edges:', DG.number_of_nodes(), DG.number_of_edges())

# %%
# (Notebook includes sampling subgraph, removing isolated nodes, computing jaccard coefficients and histogram.)

# %% [markdown]
# ## Part III — Karate Club Centralities
# Load karate_edges_list.txt and compute degree, betweenness, closeness centralities; show top-5 and scatter plot.

# %%
# Notebook includes centrality computations and scatter plot code.
