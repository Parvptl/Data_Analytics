# %% [markdown]
# # Data Smoothing and Visualization
# ### Author: Parv
# This notebook contains solutions for DS3030 Lab 4.
# It covers z-score analysis, moving averages, aggregation, and visualization across multiple datasets.

# %% [markdown]
# ## Part 1 – Industrial Characteristics Dataset
# ### Q1. Z-Score Analysis of Fixed Capital
# ### Q2. 3-Point Moving Average on Wage Data

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('indian_food.csv')
df['total_time'] = df['prep_time']+df['cook_time']

# %% [markdown]
# Calculate z-scores for Fixed Capital across all states. Identify states with z-scores ≥ ±2.5 (outliers).
# Which states have exceptionally high or low industrial fixed capital?

# %%
# Q1
from scipy import stats

icd = pd.read_csv('q1.csv')
icd['z_score'] = stats.zscore(icd['Fixed Capital'])
icd[['State','z_score']]

# %% [markdown]
# Q2
# Apply 3-point moving average to smooth wage related data that is Wages to Workers, Total
# Emoluments, and Net Income across states.

# %% [markdown]
# # Q3
# Load the dataset IHHL.csv and compute the total achieved IHHL (column “IHHLTotalAch”) of all the
# districts in each state. Print the results and verify.

# %%
plt.scatter(ihhl_inlier.index , af[ihhl_inlier.index] , color = 'blue')
plt.scatter(ihhl_outlier.index , af[ihhl_outlier.index] , color = 'red')
plt.xlabel("State")
plt.ylabel("IHHL VALUE")
plt.xticks(rotation=90)

# %% [markdown]
# ## Part 2 – IHHL Dataset Analysis
# ### Q3. State-wise Total Achieved IHHL
# ### Q4. Scatter Plot with Outlier Highlighting

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('indian_food.csv')
df['total_time'] = df['prep_time']+df['cook_time']

# %% [markdown]
# Calculate z-scores for Fixed Capital across all states. Identify states with z-scores ≥ ±2.5 (outliers).
# Which states have exceptionally high or low industrial fixed capital?

# %%
# Q1
from scipy import stats

icd = pd.read_csv('q1.csv')
icd['z_score'] = stats.zscore(icd['Fixed Capital'])
icd[['State','z_score']]

# %% [markdown]
# Q2
# Apply 3-point moving average to smooth wage related data that is Wages to Workers, Total
# Emoluments, and Net Income across states.

# %% [markdown]
# # Q3
# Load the dataset IHHL.csv and compute the total achieved IHHL (column “IHHLTotalAch”) of all the
# districts in each state. Print the results and verify.

# %%
plt.scatter(ihhl_inlier.index , af[ihhl_inlier.index] , color = 'blue')
plt.scatter(ihhl_outlier.index , af[ihhl_outlier.index] , color = 'red')
plt.xlabel("State")
plt.ylabel("IHHL VALUE")
plt.xticks(rotation=90)

# %% [markdown]
# ## Part 3 – Indian Food Dataset Analysis
# ### Q5. Average Total Cooking Time by State
# ### Q6. Pie Chart of Top 8 States by Average Cooking Time

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('indian_food.csv')
df['total_time'] = df['prep_time']+df['cook_time']

# %% [markdown]
# Calculate z-scores for Fixed Capital across all states. Identify states with z-scores ≥ ±2.5 (outliers).
# Which states have exceptionally high or low industrial fixed capital?

# %%
# Q1
from scipy import stats

icd = pd.read_csv('q1.csv')
icd['z_score'] = stats.zscore(icd['Fixed Capital'])
icd[['State','z_score']]

# %% [markdown]
# Q2
# Apply 3-point moving average to smooth wage related data that is Wages to Workers, Total
# Emoluments, and Net Income across states.

# %% [markdown]
# # Q3
# Load the dataset IHHL.csv and compute the total achieved IHHL (column “IHHLTotalAch”) of all the
# districts in each state. Print the results and verify.

# %%
plt.scatter(ihhl_inlier.index , af[ihhl_inlier.index] , color = 'blue')
plt.scatter(ihhl_outlier.index , af[ihhl_outlier.index] , color = 'red')
plt.xlabel("State")
plt.ylabel("IHHL VALUE")
plt.xticks(rotation=90)
